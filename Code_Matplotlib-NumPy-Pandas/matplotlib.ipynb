# %%
from matplotlib import pyplot as plt
# 导入pyplot模块
# as 取别名  约定俗成plt

# %% [markdown]
# ## 支持的绘制(图表)类型[](https://gengzhige-essay.readthedocs.io/docs/01%20%E7%8E%AF%E5%A2%83%E9%85%8D%E7%BD%AE/1-4%20matplotlib%E5%BF%AB%E9%80%9F%E4%B8%8A%E6%89%8B.html#id6 "永久链接至标题")
#
# | 编号 | 函数 | 描述 |
# | --- | --- | --- |
# | 1 | Bar | 绘制条形图(柱状图)。 |
# | 2 | Barh | 绘制水平条形图。 |
# | 3 | Boxplot | 绘制一个箱形和须图。 |
# | 4 | Hist | 绘制直方图。 |
# | 5 | hist2d | 绘作2D直方图。 |
# | 6 | Pie | 绘制饼图。 |
# | 7 | Plot | 绘制轴的线和/或标记。 |
# | 8 | Polar | 绘制一个极坐标图。 |
# | 9 | Scatter | 绘制x与y的散点图。 |
# | 10 | Stackplot | 绘制堆积区域图。 |
# | 11 | Stem | 绘制杆图 |
# | 12 | Step | 绘制步骤图。 |
# | 13 | Quiver | 绘制二维箭头字段。 |

# %%
# 数据在x轴的位置 
x = range(2, 26, 2)
# 数据在y轴的位置
y = [11, 23, 11.3, 35, 45, 65, 35, 27, 76, 8, 11, 45]

# %%
# 传入x y 通过plot绘制出折线图
plt.plot(x, y)
# 展示图表
plt.show()

# %%
fig = plt.figure(figsize=(10,5),dpi=100)
plt.plot(x,y)
plt.show()

# figure图形图标的意思，在这里指的就是我们要画的图
# 通过实例化一个figure并且传递参数，能够在后台自动使用该figure实例
# figsize 用来设置图像大小
# 在图像模糊的时候 可以传入dpi参数来让图片更加清晰
# savefig 保存图片
# 参数为 图像名称以及格式
# 可以保存为svg矢量图格式，放大不会有锯齿
# plt.savefig("name.png")

# %%
plt.plot(x,y)
plt.xticks(x)
# 设置y轴的刻度
#plt.yticks(y)
plt.yticks(range(min(y), max(y)+1)[::5])
plt.show()

# %% [markdown]
# ### xticks(ticks, [labels], **kwargs)
#
# 举个例子：
# **plt.xticks(x,calendar.month_name[1:13],color='blue',rotation=60)  #参数x空值X轴的间隔，第二个参数控制每个间隔显示的文本，后面两个参数控制标签的颜色和旋转角度**
#
# 星号：https://www.cnblogs.com/empty16/p/6229538.html

# %%
from matplotlib import pyplot as plt
import random
x = range(0, 60)
y = [random.randint(10, 40) for i in range(60)]
plt.plot(x, y)
# 调整x轴刻度
_x = x[::5]
_xtick_labels = ["{}分钟".format(i) for i in _x]
# plt.xticks(_x, _xtick_labels)
# rotation 刻度旋转
plt.xticks(_x, _xtick_labels, rotation=50, fontproperties="STSong")
plt.show()

# %%
from matplotlib import pyplot as plt
import random
# 设置字体 matplotlib.rc
import matplotlib
font = {"family":"MicroSoft YaHei",
       "weight":"bold",
       "size":"12"}
matplotlib.rc("font", **font)
# matplotlib.rc("font", family="MicroSoft YaHei")

x = range(0, 60)
y = [random.randint(10, 40) for i in range(60)]
plt.plot(x, y)
_x = x[::5]
_xtick_labels = ["{}分钟".format(i) for i in _x]
plt.xticks(_x, _xtick_labels, rotation=50)
plt.show()

# %%
from matplotlib import pyplot as plt
import random
# 设置字体
import matplotlib
font = {"family":"MicroSoft YaHei",
       "weight":"bold",
       "size":"12"}
matplotlib.rc("font", **font)

x = range(0, 60)
y = [random.randint(10, 40) for i in range(60)]

plt.plot(x, y)
_x = x[::5]
_xtick_labels = ["{}分钟".format(i) for i in _x]
plt.xticks(_x, _xtick_labels, rotation=50)
# 添加x轴描述信息
plt.xlabel("时间")
# 设置y轴表述信息
plt.ylabel("温度")
# 设置标题
plt.title("每分钟气温变化图")
plt.show()

# %%
font = {"family":"MicroSoft YaHei",
       "weight":"bold",
       "size":"12"}
matplotlib.rc("font", **font)
x = range(0, 60)
y = [random.randint(10, 40) for i in range(60)]

plt.plot(x, y)
_x = x[::5]
_xtick_labels = ["{}分钟".format(i) for i in _x]
plt.xticks(_x, _xtick_labels, rotation=50)
plt.xlabel("时间")
plt.ylabel("温度")
plt.title("每分钟气温变化")
# 绘制网格
# plt.grid()
# alpha 设置透明度
plt.grid(alpha=0.4)
plt.show()

# %%
plt.plot(x, y,
        color="red",# 线条颜色
        linestyle="--",# 线条风格
        linewidth=2,# 线条粗细
        alpha=0.5 #透明度
        )
_x = x[::5]
_xtick_labels = ["{}min分钟".format(i) for i in _x]
plt.xticks(_x, _xtick_labels, rotation=50)
plt.xlabel("时间")
plt.ylabel("温度")
plt.title("每分钟气温变化")
plt.grid(alpha=0.4)
plt.show()

# %%
x=range(0,60)
y=[random.randint(10,40) for _ in range(60)]
plt.scatter(x,y)#散点图
plt.bar(x,y)#条形图
plt.show()

# %%
from matplotlib import pyplot as plt
import random
plt.rcParams['font.sans-serif'] = ['SimHei'] 
x = range(0, 60)
y = [random.randint(10, 40) for i in range(60)]
plt.scatter(x, y,)
#  设置文字水印
plt.text(30, 20, "这是水印", size=30, rotation=20, alpha=0.4, color="red")
plt.show()

# %% [markdown]
# **剩下的就是通过python基本语法操作了**
#
# to be continue。。。。。
